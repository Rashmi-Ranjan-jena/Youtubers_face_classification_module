# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#First we need to load the required XML classifiers. Then load our input image (or video) in gray scale mode.

# %%
img=cv2.imread(r"C:\Users\RASHMI RANJAN JENA\Desktop\Jupyter\Celebrities_face_recognition_module\model\test_images\th.jpg")

# %%
img.shape
# Out:
# (176, 205, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (176, 205)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascad = cv2.CasecadeClassifier(r"C:\Users\RASHMI RANJAN JENA\Desktop\Jupyter\Celebrities_face_recognition_module\model\opencv\haarcascades\haarcascade_frontalcatface_extended.xml")
